# %% [markdown]
# # More examples for clustering

# %% [markdown]
# ### Helper functions

# %%
import numpy as np

def load_labeled_data(filename):
    X = []
    y = []
    with open(filename) as fp:
        for line in fp:
            temp = line.split()
            X.append(temp[:-1])
            y.append(temp[-1])
    return np.array(X, dtype = float), np.array(y, dtype = float)

def load_unlabeled_data(filename):
    X = []
    with open(filename) as fp:
        for line in fp:
            X.append(line.split())
    return np.array(X, dtype = float)

# %%
from sklearn.metrics.cluster import completeness_score
from sklearn.metrics.cluster import homogeneity_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import calinski_harabaz_score

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
# %matplotlib inline

def plot_unlabeled(X):
    fig = plt.figure(figsize = (10,10))
    plt.scatter(X[:,0], X[:,1],s=10)
    plt.show()
    return

def plot_labeled(X,y):
    fig = plt.figure(figsize = (10,10))
    cmap = plt.get_cmap('PiYG')
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], y=X[y == cl, 1],
                   cmap=cmap, label=cl)
    plt.legend()
    plt.show()
    return

def plot_3D_unlabeled(X):    
    fig = plt.figure(figsize = (10,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(X[:,0], X[:,1], X[:,2], marker='o')
    plt.show()
    return

def plot_3D_labeled(X,y):    
    fig = plt.figure(figsize = (10,10))
    ax = fig.add_subplot(111, projection='3d')

    
    cmap = plt.get_cmap('PiYG')
    for idx, cl in enumerate(np.unique(y)):
        ax.scatter(X[y == cl, 0], X[y == cl, 1], X[y == cl, 2],
                   cmap=cmap, label=cl)
    plt.legend()
    plt.show()
    return

def plot_MNIST(X):    
    plt.imshow(X.reshape(28, 28))
    plt.show()
    return

# %% [markdown]
# ### Datasets provided to you
# * data/labeled_Aggregation.txt
# * data/labeled_Compound.txt
# * data/labeled_D31.txt
# * data/labeled_Spiral.txt
# * data/unlabeled_ConfLongDemo.txt
# * data/unlabeled_Unbalanced.txt

# %%
# Load data
X,y = load_labeled_data("data/labeled_Aggregation.txt")

#X,y = load_labeled_data("data/labeled_Compound.txt")
#X,y = load_labeled_data("data/labeled_D31.txt")
#X,y = load_labeled_data("data/labeled_Spiral.txt")
#X = load_unlabeled_data("data/labeled_ConfLongDemo.txt")
#X = load_unlabeled_data("data/labeled_Unbalanced.txt")

plot_labeled(X,y)

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans, MeanShift
from sklearn.cluster import DBSCAN

# %%
# k-means with 7 clusters
model= KMeans(n_clusters=7)
model.fit(X)
labels = model.predict(X)
plot_labeled(X,labels)

# %%
# k-means compare, won't be the same everytime because initial condition dependent
model= KMeans(n_clusters=7)
model.fit(X)
labels = model.predict(X)
plot_labeled(X,labels)

# %%
# Agglomerative Clustering (hierarchical)

model= AgglomerativeClustering(n_clusters=7)
model.fit(X)
labels = model.labels_
plot_labeled(X,labels)

# %%
# Different dataset
X,y = load_labeled_data("data/labeled_Spiral.txt")
plot_labeled(X,y)

# %%
# DBSCAN
model = DBSCAN()
model.fit(X)
labels = model.labels_
plot_labeled(X,labels)

# %%
# tuning DBSCAN hyper parameters
model = DBSCAN(min_samples = 1, eps = 3)
model.fit(X)
labels = model.labels_
plot_labeled(X,labels)

# %%
# 3D dataset
X = load_unlabeled_data("data/unlabeled_ConfLongDemo.txt")
plot_3D_unlabeled(X)

# %%
# clustering with k-means
 
model= KMeans(n_clusters=7)
model.fit(X)
labels = model.predict(X)
plot_3D_labeled(X,labels)

# %%
X = load_unlabeled_data("data/unlabeled_Unbalanced.txt")

plot_unlabeled(X)

# %%
model= KMeans(n_clusters=8)
model.fit(X)
labels = model.labels_
plot_labeled(X,labels)

# %% [markdown]
# # Short introduction to dimension reduction

# %% [markdown]
# Dimension reduction: reducing the dimension of the feature space for analysis or visualization
#
# * Feature Elimination: reduce the feature space by eliminating features
# * Feature Extraction: create “new” features, where each “new” feature is a combination of each of “old” features in a specific way. We keep as many of the new features as we want, and drop the “least important ones.”
#
# ### Principal Component Analysis
#
# ![](images/PCA_illustration.png)
#
# Tutorial: https://towardsdatascience.com/a-one-stop-shop-for-principal-component-analysis-5582fb7e0a9c

# %%
# PCA example with the 3D dataset
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
standscale= StandardScaler()
#X = load_unlabeled_data("data/unlabeled_ConfLongDemo.txt")

standscaler.fit(X)
X_scaled = standscaler.transform(X)

model=PCA(n_components=2)

model.fit(X_scaled)
X_transformed = model.transform(X_scaled)
plot_unlabeled(X_transformed) #scores plot

# %%
print(model.explained_variance_ratio_)
# Out:
# [0.72403206 0.15801337]

# %%
#calling loadings
print(model.components_)
# Out:
# [[ 0.97420437 -0.22535701  0.01183497]
#  [-0.22079511 -0.9626975  -0.15640667]]

# %% [markdown]
# ### MNIST Dataset
#
# Dataset of handwritten digits. Each datapoint is a 28 * 28 image
# ![](images/MNIST.png)

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/")
X = mnist.train.images[:5000]
y = mnist.train.labels[:5000]
# Out:
# C:\Anaconda\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From <ipython-input-34-825825f339fd>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
X.shape
# Out:
# (5000, 784)

# %%
plot_MNIST(X[1000])

# %%
# MNIST with PCA (50 components)
from sklearn.decomposition import PCA

model=PCA(n_components=50)

model.fit(X)
X_transformed = model.transform(X)
plot_labeled(X_transformed,y)

# %%
print(model.explained_variance_ratio_)
print(sum(model.explained_variance_ratio_[:30]))
# Out:
# [0.10575937 0.07077187 0.06160971 0.05463355 0.04806108 0.04397982
#  0.03221926 0.02969608 0.02825223 0.02323568 0.0210507  0.02042647
#  0.01724589 0.01682583 0.01610422 0.01531643 0.01285727 0.01260577
#  0.01143338 0.01074918 0.01060954 0.01011595 0.00956801 0.0090135
#  0.00837173 0.00820732 0.00800264 0.00773396 0.00699232 0.00691694
#  0.00647223 0.00626727 0.00595359 0.00579894 0.00551557 0.00541562
#  0.00503907 0.00479627 0.00476076 0.00463835 0.0044529  0.0042762
#  0.00402252 0.00395648 0.00366759 0.00353509 0.00348919 0.00346163
#  0.00329329 0.00320042]
# 0.7383657079190016

# %% [markdown]
# ## Other methods
# * https://towardsdatascience.com/dimensionality-reduction-toolbox-in-python-9a18995927cd
# * https://colah.github.io/posts/2014-10-Visualizing-MNIST/

# %%
from sklearn.manifold import Isomap
model = Isomap(n_components=2, n_neighbors = 5)
X_transformed = model.fit_transform(X)
plot_labeled(X_transformed,y)

# %%
from sklearn.manifold import TSNE
model = TSNE(n_components=2,learning_rate=300,perplexity = 30, verbose = 3)
X_transformed = model.fit_transform(X)
plot_labeled(X_transformed,y)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 5000 samples in 0.361s...
# [t-SNE] Computed neighbors for 5000 samples in 39.732s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 5000
# [t-SNE] Computed conditional probabilities for sample 2000 / 5000
# [t-SNE] Computed conditional probabilities for sample 3000 / 5000
# [t-SNE] Computed conditional probabilities for sample 4000 / 5000
# [t-SNE] Computed conditional probabilities for sample 5000 / 5000
# [t-SNE] Mean sigma: 2.234141
# [t-SNE] Computed conditional probabilities in 0.250s
# [t-SNE] Iteration 50: error = 88.9358215, gradient norm = 0.0039583 (50 iterations in 11.316s)
# [t-SNE] Iteration 100: error = 82.6326981, gradient norm = 0.0050017 (50 iterations in 10.519s)
# [t-SNE] Iteration 150: error = 82.0853882, gradient norm = 0.0004858 (50 iterations in 9.234s)
# [t-SNE] Iteration 200: error = 82.0736313, gradient norm = 0.0009352 (50 iterations in 9.176s)
# [t-SNE] Iteration 250: error = 82.0754013, gradient norm = 0.0001500 (50 iterations in 9.252s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 82.075401
# [t-SNE] Iteration 300: error = 2.0948272, gradient norm = 0.0008732 (50 iterations in 8.058s)
# [t-SNE] Iteration 350: error = 1.7874255, gradient norm = 0.0003581 (50 iterations in 7.874s)
# [t-SNE] Iteration 400: error = 1.6625193, gradient norm = 0.0002172 (50 iterations in 7.918s)
# [t-SNE] Iteration 450: error = 1.5969553, gradient norm = 0.0001636 (50 iterations in 8.013s)
# [t-SNE] Iteration 500: error = 1.5583595, gradient norm = 0.0001236 (50 iterations in 7.997s)
# [t-SNE] Iteration 550: error = 1.5337738, gradient norm = 0.0001132 (50 iterations in 8.075s)
# [t-SNE] Iteration 600: error = 1.5172483, gradient norm = 0.0000880 (50 iterations in 8.171s)
# [t-SNE] Iteration 650: error = 1.5051322, gradient norm = 0.0000764 (50 iterations in 8.206s)
# [t-SNE] Iteration 700: error = 1.4958045, gradient norm = 0.0000699 (50 iterations in 8.094s)
# [t-SNE] Iteration 750: error = 1.4881903, gradient norm = 0.0000658 (50 iterations in 8.251s)
# [t-SNE] Iteration 800: error = 1.4822822, gradient norm = 0.0000606 (50 iterations in 8.120s)
# [t-SNE] Iteration 850: error = 1.4773828, gradient norm = 0.0000562 (50 iterations in 8.093s)
# [t-SNE] Iteration 900: error = 1.4732138, gradient norm = 0.0000548 (50 iterations in 8.075s)
# [t-SNE] Iteration 950: error = 1.4697915, gradient norm = 0.0000513 (50 iterations in 8.176s)
# [t-SNE] Iteration 1000: error = 1.4668040, gradient norm = 0.0000501 (50 iterations in 8.250s)
# [t-SNE] Error after 1000 iterations: 1.466804

# %% [markdown]
# # Q&A Session
